# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("groot1.jpg")

# %% [markdown]
# Show Image using OpenCV

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=92x137 at 0x7FE00C4A9D50>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Image in gray

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=92x137 at 0x7FE00BC45E10>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %% [markdown]
# Image in invert

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=92x137 at 0x7FE00BC4D5D0>

# %% [markdown]
# Image smoothing

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=92x137 at 0x7FE00C4A9490>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# Final image in Sketch

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=92x137 at 0x7FE00C4B5DD0>
